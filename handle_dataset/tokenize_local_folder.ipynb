# %%
from datasets import load_dataset

name_to_push_dataset_to = "cubbk/rixvox-tokenised"


df = load_dataset("parquet", data_files="../dataset/dev_metadata.parquet")["train"].select(range(10)) # type: ignore

df = df.remove_columns(["dokid", "anforande_nummer", "observation_nr", "speaker", "party", "gender", "debatedate", "electoral_district", "birth_year", "intressent_id", "speaker_from_id", "speaker_audio_meta", "start", "end", "duration", "bleu_score", "speaker_total_hours"])

df
# Out:
# Dataset({
#     features: ['text', 'filename'],
#     num_rows: 10
# })

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
import torch
from snac import SNAC


model = SNAC.from_pretrained("hubertsiuzdak/snac_24khz")
model.to("cpu")
# Out:
# SNAC(
#   (encoder): Encoder(
#     (block): Sequential(
#       (0): ParametrizedConv1d(
#         1, 48, kernel_size=(7,), stride=(1,), padding=(3,)
#         (parametrizations): ModuleDict(
#           (weight): ParametrizationList(
#             (0): _WeightNorm()
#           )
#         )
#       )
#       (1): EncoderBlock(
#         (block): Sequential(
#           (0): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 48, 48, kernel_size=(7,), stride=(1,), padding=(3,), groups=48
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 48, 48, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (1): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 48, 48, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,), groups=48
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 48, 48, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (2): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 48, 48, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,), groups=48
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 48, 48, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (3): Snake1d()
#           (4): ParametrizedConv1d(
#             48, 96, kernel_size=(4,), stride=(2,), padding=(1,)
#             (parametrizations): ModuleDict(
#               (weight): ParametrizationList(
#                 (0): _WeightNorm()
#               )
#             )
#           )
#         )
#       )
#       (2): EncoderBlock(
#         (block): Sequential(
#           (0): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 96, 96, kernel_size=(7,), stride=(1,), padding=(3,), groups=96
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 96, 96, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (1): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 96, 96, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,), groups=96
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 96, 96, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (2): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 96, 96, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,), groups=96
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 96, 96, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (3): Snake1d()
#           (4): ParametrizedConv1d(
#             96, 192, kernel_size=(8,), stride=(4,), padding=(2,)
#             (parametrizations): ModuleDict(
#               (weight): ParametrizationList(
#                 (0): _WeightNorm()
#               )
#             )
#           )
#         )
#       )
#       (3): EncoderBlock(
#         (block): Sequential(
#           (0): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 192, 192, kernel_size=(7,), stride=(1,), padding=(3,), groups=192
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 192, 192, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (1): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 192, 192, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,), groups=192
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 192, 192, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (2): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 192, 192, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,), groups=192
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 192, 192, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (3): Snake1d()
#           (4): ParametrizedConv1d(
#             192, 384, kernel_size=(16,), stride=(8,), padding=(4,)
#             (parametrizations): ModuleDict(
#               (weight): ParametrizationList(
#                 (0): _WeightNorm()
#               )
#             )
#           )
#         )
#       )
#       (4): EncoderBlock(
#         (block): Sequential(
#           (0): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 384, 384, kernel_size=(7,), stride=(1,), padding=(3,), groups=384
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 384, 384, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (1): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 384, 384, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,), groups=384
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 384, 384, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (2): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 384, 384, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,), groups=384
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 384, 384, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (3): Snake1d()
#           (4): ParametrizedConv1d(
#             384, 768, kernel_size=(16,), stride=(8,), padding=(4,)
#             (parametrizations): ModuleDict(
#               (weight): ParametrizationList(
#                 (0): _WeightNorm()
#               )
#             )
#           )
#         )
#       )
#       (5): ParametrizedConv1d(
#         768, 768, kernel_size=(7,), stride=(1,), padding=(3,), groups=768
#         (parametrizations): ModuleDict(
#           (weight): ParametrizationList(
#             (0): _WeightNorm()
#           )
#         )
#       )
#     )
#   )
#   (quantizer): ResidualVectorQuantize(
#     (quantizers): ModuleList(
#       (0-2): 3 x VectorQuantize(
#         (in_proj): ParametrizedConv1d(
#           768, 8, kernel_size=(1,), stride=(1,)
#           (parametrizations): ModuleDict(
#             (weight): ParametrizationList(
#               (0): _WeightNorm()
#             )
#           )
#         )
#         (out_proj): ParametrizedConv1d(
#           8, 768, kernel_size=(1,), stride=(1,)
#           (parametrizations): ModuleDict(
#             (weight): ParametrizationList(
#               (0): _WeightNorm()
#             )
#           )
#         )
#         (codebook): Embedding(4096, 8)
#       )
#     )
#   )
#   (decoder): Decoder(
#     (model): Sequential(
#       (0): ParametrizedConv1d(
#         768, 768, kernel_size=(7,), stride=(1,), padding=(3,), groups=768
#         (parametrizations): ModuleDict(
#           (weight): ParametrizationList(
#             (0): _WeightNorm()
#           )
#         )
#       )
#       (1): ParametrizedConv1d(
#         768, 1024, kernel_size=(1,), stride=(1,)
#         (parametrizations): ModuleDict(
#           (weight): ParametrizationList(
#             (0): _WeightNorm()
#           )
#         )
#       )
#       (2): DecoderBlock(
#         (block): Sequential(
#           (0): Snake1d()
#           (1): ParametrizedConvTranspose1d(
#             1024, 512, kernel_size=(16,), stride=(8,), padding=(4,)
#             (parametrizations): ModuleDict(
#               (weight): ParametrizationList(
#                 (0): _WeightNorm()
#               )
#             )
#           )
#           (2): NoiseBlock(
#             (linear): ParametrizedConv1d(
#               512, 512, kernel_size=(1,), stride=(1,), bias=False
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#           (3): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 512, 512, kernel_size=(7,), stride=(1,), padding=(3,), groups=512
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 512, 512, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (4): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 512, 512, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,), groups=512
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 512, 512, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (5): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 512, 512, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,), groups=512
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 512, 512, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#       (3): DecoderBlock(
#         (block): Sequential(
#           (0): Snake1d()
#           (1): ParametrizedConvTranspose1d(
#             512, 256, kernel_size=(16,), stride=(8,), padding=(4,)
#             (parametrizations): ModuleDict(
#               (weight): ParametrizationList(
#                 (0): _WeightNorm()
#               )
#             )
#           )
#           (2): NoiseBlock(
#             (linear): ParametrizedConv1d(
#               256, 256, kernel_size=(1,), stride=(1,), bias=False
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#           (3): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 256, 256, kernel_size=(7,), stride=(1,), padding=(3,), groups=256
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 256, 256, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (4): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 256, 256, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,), groups=256
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 256, 256, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (5): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 256, 256, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,), groups=256
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 256, 256, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#       (4): DecoderBlock(
#         (block): Sequential(
#           (0): Snake1d()
#           (1): ParametrizedConvTranspose1d(
#             256, 128, kernel_size=(8,), stride=(4,), padding=(2,)
#             (parametrizations): ModuleDict(
#               (weight): ParametrizationList(
#                 (0): _WeightNorm()
#               )
#             )
#           )
#           (2): NoiseBlock(
#             (linear): ParametrizedConv1d(
#               128, 128, kernel_size=(1,), stride=(1,), bias=False
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#           (3): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 128, 128, kernel_size=(7,), stride=(1,), padding=(3,), groups=128
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 128, 128, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (4): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 128, 128, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,), groups=128
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 128, 128, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (5): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 128, 128, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,), groups=128
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 128, 128, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#       (5): DecoderBlock(
#         (block): Sequential(
#           (0): Snake1d()
#           (1): ParametrizedConvTranspose1d(
#             128, 64, kernel_size=(4,), stride=(2,), padding=(1,)
#             (parametrizations): ModuleDict(
#               (weight): ParametrizationList(
#                 (0): _WeightNorm()
#               )
#             )
#           )
#           (2): NoiseBlock(
#             (linear): ParametrizedConv1d(
#               64, 64, kernel_size=(1,), stride=(1,), bias=False
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#           (3): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 64, 64, kernel_size=(7,), stride=(1,), padding=(3,), groups=64
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 64, 64, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (4): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 64, 64, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,), groups=64
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 64, 64, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (5): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): ParametrizedConv1d(
#                 64, 64, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,), groups=64
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): Snake1d()
#               (3): ParametrizedConv1d(
#                 64, 64, kernel_size=(1,), stride=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#       (6): Snake1d()
#       (7): ParametrizedConv1d(
#         64, 1, kernel_size=(7,), stride=(1,), padding=(3,)
#         (parametrizations): ModuleDict(
#           (weight): ParametrizationList(
#             (0): _WeightNorm()
#           )
#         )
#       )
#       (8): Tanh()
#     )
#   )
# )

# %%
#@title Tokenisation Function
import torchaudio.transforms as T
from datasets import Audio

def tokenise_audio(waveform, sp):
  waveform = torch.from_numpy(waveform).unsqueeze(0)
  waveform = waveform.to(dtype=torch.float32)
  resample_transform = T.Resample(orig_freq=sp, new_freq=24000)
  waveform = resample_transform(waveform)
  waveform = waveform.unsqueeze(0).to("cpu")
  #generate the codes from snac
  with torch.inference_mode():
    codes = model.encode(waveform)

  all_codes = []
  for i in range(codes[0].shape[1]):
    all_codes.append(codes[0][0][i].item()+128266)
    all_codes.append(codes[1][0][2*i].item()+128266+4096)
    all_codes.append(codes[2][0][4*i].item()+128266+(2*4096))
    all_codes.append(codes[2][0][(4*i)+1].item()+128266+(3*4096))
    all_codes.append(codes[1][0][(2*i)+1].item()+128266+(4*4096))
    all_codes.append(codes[2][0][(4*i)+2].item()+128266+(5*4096))
    all_codes.append(codes[2][0][(4*i)+3].item()+128266+(6*4096))


  return all_codes

# %%
import os
import numpy as np
import soundfile as sf
from datasets import Dataset

# Build path column
ds = df.map(lambda ex: {"audio_path": os.path.join("../dataset/dev/", ex["filename"])}) # type: ignore

def load_audio(example):
    y, sr = sf.read(example["audio_path"])
    if y.ndim > 1:
        y = np.mean(y, axis=1)  # mono
    example["waveform"] = y.astype("float32")
    example["sampling_rate"] = sr
    return example

ds = ds.map(load_audio)

ds[0]["sampling_rate"] # type: ignore
# Out:
# Map:   0%|          | 0/10 [00:00<?, ? examples/s]
# Map:   0%|          | 0/10 [00:00<?, ? examples/s]
# 16000

# %%
def add_codes(example):
    wf = np.asarray(example["waveform"], dtype=np.float32)  # ensure ndarray
    example["codes_list"] = tokenise_audio(wf, example["sampling_rate"])
    return example

ds = ds.map(add_codes, remove_columns=["waveform","sampling_rate","audio_path"])
# Out:
# Map:   0%|          | 0/10 [00:00<?, ? examples/s]

# %%
#@title Load Tokenizer
tokeniser_length = 128256
start_of_text = 128000
end_of_text = 128009

start_of_speech = tokeniser_length + 1
end_of_speech = tokeniser_length + 2

start_of_human = tokeniser_length + 3
# Filter:   0%|          | 0/10 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/10 [00:00<?, ? examples/s]

# %%
#@title Create Input Ids
def remove_duplicate_frames(example):
    vals = example["codes_list"]
    if len(vals) % 7 != 0:
        raise ValueError("Input list length must be divisible by 7")

    result = vals[:7]

    removed_frames = 0

    for i in range(7, len(vals), 7):
        current_first = vals[i]
        previous_first = result[-7]

        if current_first != previous_first:
            result.extend(vals[i:i+7])
        else:
            removed_frames += 1

    example["codes_list"] = result

    return example

ds = ds.map(remove_duplicate_frames, num_proc=num_proc)

tok_info = '''*** HERE you can modify the text prompt
i.e. if you wanted a multispeaker model like canopylabs/orpheus-3b-0.1-ft, you can pass:
f"{example["source"]}:  {example["text"]}", as is passed.
'''
print(tok_info)

def create_input_ids(example):
    text_ids = tokenizer.encode(example["text"],  add_special_tokens=True)
    text_ids.append(end_of_text)
    example["text_tokens"] = text_ids
    input_ids = (
        [start_of_human]
        + example["text_tokens"]
        + [end_of_human]
        + [start_of_ai]
        + [start_of_speech]
        + example["codes_list"]
        + [end_of_speech]
        + [end_of_ai]
    )
    example["input_ids"] = input_ids
    example["labels"] = input_ids
    example["attention_mask"] = [1] * len(input_ids)

    return example

ds = ds.map(create_input_ids, num_proc=num_proc, remove_columns=["text", "codes_list"])

ds
# Out:
# Map (num_proc=8):   0%|          | 0/10 [00:00<?, ? examples/s]
# *** HERE you can modify the text prompt
# i.e. if you wanted a multispeaker model like canopylabs/orpheus-3b-0.1-ft, you can pass:
# f"{example["source"]}:  {example["text"]}", as is passed.
# Map (num_proc=8):   0%|          | 0/10 [00:00<?, ? examples/s]
# Dataset({
#     features: ['filename', 'text_tokens', 'input_ids', 'labels', 'attention_mask'],
#     num_rows: 10
# })

# %%
columns_to_keep = ["input_ids", "labels", "attention_mask"]
columns_to_remove = [col for col in ds.column_names if col not in columns_to_keep]

ds = ds.remove_columns(columns_to_remove)

# %%
ds.push_to_hub(name_to_push_dataset_to)
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#                                         : 100%|##########|  135kB /  135kB
# CommitInfo(commit_url='https://huggingface.co/datasets/cubbk/rixvox-tokenised/commit/6aacf5aa5aab29eb8097112600d3ab5ca598536b', commit_message='Upload dataset', commit_description='', oid='6aacf5aa5aab29eb8097112600d3ab5ca598536b', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/cubbk/rixvox-tokenised', endpoint='https://huggingface.co', repo_type='dataset', repo_id='cubbk/rixvox-tokenised'), pr_revision=None, pr_num=None)
